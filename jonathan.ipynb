# %%
import pandas as pd

spain_data = pd.read_excel('Data/spain_data.xlsx', header = 2)
us_data = pd.read_excel('Data/us_data.xlsx', header = 2)

# %%
spain_data.rename(columns={'Unnamed: 0': 'Date'})
# Out:
#          Date  Economic Activity, Industrial Production, Index  \
# 0    Jan 1960                                              NaN
# 1    Feb 1960                                              NaN
# 2    Mar 1960                                              NaN
# 3    Apr 1960                                              NaN
# 4    May 1960                                              NaN
# ..        ...                                              ...
# 367  Aug 1990                                        57.138375
# 368  Sep 1990                                        97.803577
# 369  Oct 1990                                       100.909947
# 370  Nov 1990                                       104.110449
# 371  Dec 1990                                        88.202071
#
#      Exchange Rates, National Currency Per U.S. Dollar, Period Average, Rate  \
# 0                                               60.000
# 1                                               60.000
# ...

# %%
us_data.rename(columns={'Unnamed: 0': 'Date'})
# Out:
#          Date  \
# 0    Jan 1960
# 1    Feb 1960
# 2    Mar 1960
# 3    Apr 1960
# 4    May 1960
# ..        ...
# 367  Aug 1990
# 368  Sep 1990
# 369  Oct 1990
# 370  Nov 1990
# 371  Dec 1990
#
#      International Reserves and Liquidity, Reserves, Official Reserve Assets, US Dollar  \
# 0                                         21478.100000
# 1                                         21395.700000
# 2                                         21344.700000
# 3                                         21278.000000
# 4                                         21234.300000
# ..                                                 ...
# 367                                       78908.838357
# 368                                       80024.166133
# 369                                       82852.196532
# 370                                       83059.402774
# 371                                       83316.214608
#
#      Prices, Consumer Price Index, All items, Index
# ...

# %%
pd.merge(spain_data, us_data, on='Unnamed: 0')
# Out:
#     Unnamed: 0  Economic Activity, Industrial Production, Index  \
# 0     Jan 1960                                              NaN
# 1     Feb 1960                                              NaN
# 2     Mar 1960                                              NaN
# 3     Apr 1960                                              NaN
# 4     May 1960                                              NaN
# ..         ...                                              ...
# 367   Aug 1990                                        57.138375
# 368   Sep 1990                                        97.803577
# 369   Oct 1990                                       100.909947
# 370   Nov 1990                                       104.110449
# 371   Dec 1990                                        88.202071
#
#      Exchange Rates, National Currency Per U.S. Dollar, Period Average, Rate  \
# 0                                               60.000
# 1                                               60.000
# ...
